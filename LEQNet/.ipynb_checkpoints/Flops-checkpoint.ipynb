# %%
from EQTransformer.core.trainer import trainer
trainer(input_hdf5='../data/STEAD/merge_modified.hdf5',
        input_csv='../data/STEAD/mix_train_merge_modified.csv',
        output_name='test_trainer',                
        cnn_blocks=4,
        lstm_blocks=2,
        padding='same',
        activation='relu',
        label_type='gaussian',
        mode='generator',
        train_valid_test_split=[0.80, 0.10, 0.10],
        batch_size=20,
        epochs=10, 
        patience=2,
        gpuid=None,
        gpu_limit=None)
# Out:
# Learning rate:  0.001
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 6000, 3)      0
# __________________________________________________________________________________________________
# separable_conv1d_21 (SeparableC (None, 6000, 8)      65          input[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 2000, 8)      0           separable_conv1d_21[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_22 (SeparableC (None, 2000, 16)     216         max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 667, 16)      0           separable_conv1d_22[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_23 (SeparableC (None, 667, 16)      384         max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 223, 16)      0           separable_conv1d_23[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_24 (SeparableC (None, 223, 32)      656         max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_9 (MaxPooling1D)  (None, 112, 32)      0           separable_conv1d_24[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_25 (SeparableC (None, 112, 64)      2272        max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_10 (MaxPooling1D) (None, 56, 64)       0           separable_conv1d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 56, 64)       256         max_pooling1d_10[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 56, 64)       0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 56, 16)       1040        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 56, 16)       64          conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 56, 16)       0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_5 (SpatialDro (None, 56, 16)       0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 56, 16)       784         spatial_dropout1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 56, 16)       64          conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 56, 16)       0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 56, 64)       1088        activation_15[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 56, 64)       0           max_pooling1d_10[0][0]
#                                                                  conv1d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 56, 64)       256         add_9[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 56, 64)       0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 56, 16)       1040        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 56, 16)       64          conv1d_18[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 56, 16)       0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_6 (SpatialDro (None, 56, 16)       0           activation_17[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 56, 16)       784         spatial_dropout1d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 56, 16)       64          conv1d_19[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 56, 16)       0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 56, 64)       1088        activation_18[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 56, 64)       0           add_9[0][0]
#                                                                  conv1d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 56, 64)       256         add_10[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 56, 64)       0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 56, 16)       1040        activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 56, 16)       64          conv1d_21[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 56, 16)       0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_7 (SpatialDro (None, 56, 16)       0           activation_20[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 56, 16)       784         spatial_dropout1d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 56, 16)       64          conv1d_22[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 56, 16)       0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 56, 64)       1088        activation_21[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 56, 64)       0           add_10[0][0]
#                                                                  conv1d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 56, 64)       256         add_11[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 56, 64)       0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 56, 16)       1040        activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 56, 16)       64          conv1d_24[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 56, 16)       0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_8 (SpatialDro (None, 56, 16)       0           activation_23[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 56, 16)       528         spatial_dropout1d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 56, 16)       64          conv1d_25[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 56, 16)       0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 56, 64)       1088        activation_24[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 56, 64)       0           add_11[0][0]
#                                                                  conv1d_26[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 56, 32)       10368       add_12[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 56, 16)       528         bidirectional_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 56, 16)       64          conv1d_27[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 56, 32)       4224        batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 56, 16)       528         bidirectional_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 56, 16)       64          conv1d_28[0][0]
# __________________________________________________________________________________________________
# attentionD0 (SeqSelfAttention)  [(None, 56, 16), (No 1089        batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 56, 16)       0           batch_normalization_28[0][0]
#                                                                  attentionD0[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (None, 56, 16)       32          add_13[0][0]
# __________________________________________________________________________________________________
# feed_forward_3 (FeedForward)    (None, 56, 16)       4240        layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 56, 16)       0           layer_normalization_5[0][0]
#                                                                  feed_forward_3[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, 56, 16)       32          add_14[0][0]
# __________________________________________________________________________________________________
# attentionD (SeqSelfAttention)   [(None, 56, 16), (No 1089        layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 56, 16)       0           layer_normalization_6[0][0]
#                                                                  attentionD[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, 56, 16)       32          add_15[0][0]
# __________________________________________________________________________________________________
# feed_forward_4 (FeedForward)    (None, 56, 16)       4240        layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 56, 16)       0           layer_normalization_7[0][0]
#                                                                  feed_forward_4[0][0]
# __________________________________________________________________________________________________
# layer_normalization_8 (LayerNor (None, 56, 16)       32          add_16[0][0]
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   (None, 56, 16)       2112        layer_normalization_8[0][0]
# __________________________________________________________________________________________________
# lstm_8 (LSTM)                   (None, 56, 16)       2112        layer_normalization_8[0][0]
# __________________________________________________________________________________________________
# attentionP (SeqSelfAttention)   [(None, 56, 16), (No 1089        lstm_7[0][0]
# __________________________________________________________________________________________________
# attentionS (SeqSelfAttention)   [(None, 56, 16), (No 1089        lstm_8[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_16 (UpSampling1D) (None, 112, 16)      0           layer_normalization_8[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_21 (UpSampling1D) (None, 112, 16)      0           attentionP[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_26 (UpSampling1D) (None, 112, 16)      0           attentionS[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_26 (SeparableC (None, 112, 64)      1136        up_sampling1d_16[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_31 (SeparableC (None, 112, 64)      1136        up_sampling1d_21[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_36 (SeparableC (None, 112, 64)      1136        up_sampling1d_26[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_17 (UpSampling1D) (None, 224, 64)      0           separable_conv1d_26[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_22 (UpSampling1D) (None, 224, 64)      0           separable_conv1d_31[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_27 (UpSampling1D) (None, 224, 64)      0           separable_conv1d_36[0][0]
# __________________________________________________________________________________________________
# cropping1d_10 (Cropping1D)      (None, 223, 64)      0           up_sampling1d_17[0][0]
# __________________________________________________________________________________________________
# cropping1d_13 (Cropping1D)      (None, 223, 64)      0           up_sampling1d_22[0][0]
# __________________________________________________________________________________________________
# cropping1d_16 (Cropping1D)      (None, 223, 64)      0           up_sampling1d_27[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_27 (SeparableC (None, 223, 32)      2400        cropping1d_10[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_32 (SeparableC (None, 223, 32)      2400        cropping1d_13[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_37 (SeparableC (None, 223, 32)      2400        cropping1d_16[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_18 (UpSampling1D) (None, 669, 32)      0           separable_conv1d_27[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_23 (UpSampling1D) (None, 669, 32)      0           separable_conv1d_32[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_28 (UpSampling1D) (None, 669, 32)      0           separable_conv1d_37[0][0]
# __________________________________________________________________________________________________
# cropping1d_11 (Cropping1D)      (None, 667, 32)      0           up_sampling1d_18[0][0]
# __________________________________________________________________________________________________
# cropping1d_14 (Cropping1D)      (None, 667, 32)      0           up_sampling1d_23[0][0]
# __________________________________________________________________________________________________
# cropping1d_17 (Cropping1D)      (None, 667, 32)      0           up_sampling1d_28[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_28 (SeparableC (None, 667, 16)      688         cropping1d_11[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_33 (SeparableC (None, 667, 16)      688         cropping1d_14[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_38 (SeparableC (None, 667, 16)      688         cropping1d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_19 (UpSampling1D) (None, 2001, 16)     0           separable_conv1d_28[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_24 (UpSampling1D) (None, 2001, 16)     0           separable_conv1d_33[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_29 (UpSampling1D) (None, 2001, 16)     0           separable_conv1d_38[0][0]
# __________________________________________________________________________________________________
# cropping1d_12 (Cropping1D)      (None, 2000, 16)     0           up_sampling1d_19[0][0]
# __________________________________________________________________________________________________
# cropping1d_15 (Cropping1D)      (None, 2000, 16)     0           up_sampling1d_24[0][0]
# __________________________________________________________________________________________________
# cropping1d_18 (Cropping1D)      (None, 2000, 16)     0           up_sampling1d_29[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_29 (SeparableC (None, 2000, 16)     384         cropping1d_12[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_34 (SeparableC (None, 2000, 16)     384         cropping1d_15[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_39 (SeparableC (None, 2000, 16)     384         cropping1d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_20 (UpSampling1D) (None, 6000, 16)     0           separable_conv1d_29[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_25 (UpSampling1D) (None, 6000, 16)     0           separable_conv1d_34[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_30 (UpSampling1D) (None, 6000, 16)     0           separable_conv1d_39[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_30 (SeparableC (None, 6000, 8)      248         up_sampling1d_20[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_35 (SeparableC (None, 6000, 8)      248         up_sampling1d_25[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_40 (SeparableC (None, 6000, 8)      248         up_sampling1d_30[0][0]
# __________________________________________________________________________________________________
# detector (Conv1D)               (None, 6000, 1)      89          separable_conv1d_30[0][0]
# __________________________________________________________________________________________________
# picker_P (Conv1D)               (None, 6000, 1)      89          separable_conv1d_35[0][0]
# __________________________________________________________________________________________________
# picker_S (Conv1D)               (None, 6000, 1)      89          separable_conv1d_40[0][0]
# ==================================================================================================
# Total params: 64,320
# Trainable params: 63,488
# Non-trainable params: 832
# __________________________________________________________________________________________________
# Started training in generator mode ...
# Epoch 1/10
# Learning rate:  0.001
# 7999/8000 [============================>.] - ETA: 0s - loss: 0.0124 - detector_loss: 0.0497 - picker_P_loss: 0.0104 - picker_S_loss: 0.0100 - detector_f1: 0.8442 - picker_P_f1: 0.1958 - picker_S_f1: 0.0479
# Learning rate:
# 8000/8000 [==============================] - 2938s 367ms/step - loss: 0.0124 - detector_loss: 0.0497 - picker_P_loss: 0.0104 - picker_S_loss: 0.0100 - detector_f1: 0.8442 - picker_P_f1: 0.1958 - picker_S_f1: 0.0479 - val_loss: 0.0053 - val_detector_loss: 0.0103 - val_picker_P_loss: 0.0026 - val_picker_S_loss: 0.0043 - val_detector_f1: 0.9621 - val_picker_P_f1: 0.5718 - val_picker_S_f1: 0.2423
#
# Epoch 00001: val_loss improved from inf to 0.00532, saving model to /home/volume/workspace/Project/Earthquake/Discriminate-Quarryblast/test_trainer_outputs/models/test_trainer_001.h5
# Epoch 2/10
# Learning rate:  0.001
# 8000/8000 [==============================] - 3013s 377ms/step - loss: 0.0063 - detector_loss: 0.0264 - picker_P_loss: 0.0049 - picker_S_loss: 0.0053 - detector_f1: 0.9204 - picker_P_f1: 0.4229 - picker_S_f1: 0.2634 - val_loss: 0.0036 - val_detector_loss: 0.0074 - val_picker_P_loss: 0.0022 - val_picker_S_loss: 0.0034 - val_detector_f1: 0.9734 - val_picker_P_f1: 0.6515 - val_picker_S_f1: 0.3716
#
# Epoch 00002: val_loss improved from 0.00532 to 0.00362, saving model to /home/volume/workspace/Project/Earthquake/Discriminate-Quarryblast/test_trainer_outputs/models/test_trainer_002.h5
# Epoch 3/10
# Learning rate:  0.001
# 8000/8000 [==============================] - 3050s 381ms/step - loss: 0.0058 - detector_loss: 0.0228 - picker_P_loss: 0.0045 - picker_S_loss: 0.0049 - detector_f1: 0.9300 - picker_P_f1: 0.4665 - picker_S_f1: 0.3193 - val_loss: 0.0036 - val_detector_loss: 0.0081 - val_picker_P_loss: 0.0020 - val_picker_S_loss: 0.0033 - val_detector_f1: 0.9750 - val_picker_P_f1: 0.6870 - val_picker_S_f1: 0.4457
#
# Epoch 00003: val_loss improved from 0.00362 to 0.00359, saving model to /home/volume/workspace/Project/Earthquake/Discriminate-Quarryblast/test_trainer_outputs/models/test_trainer_003.h5
# Epoch 4/10
# Learning rate:  0.001
# 8000/8000 [==============================] - 3043s 380ms/step - loss: 0.0056 - detector_loss: 0.0216 - picker_P_loss: 0.0044 - picker_S_loss: 0.0048 - detector_f1: 0.9341 - picker_P_f1: 0.4848 - picker_S_f1: 0.3440 - val_loss: 0.0035 - val_detector_loss: 0.0062 - val_picker_P_loss: 0.0020 - val_picker_S_loss: 0.0032 - val_detector_f1: 0.9778 - val_picker_P_f1: 0.6993 - val_picker_S_f1: 0.4005
#
# Epoch 00004: val_loss improved from 0.00359 to 0.00349, saving model to /home/volume/workspace/Project/Earthquake/Discriminate-Quarryblast/test_trainer_outputs/models/test_trainer_004.h5
# Epoch 5/10
# Learning rate:  0.001
# 7999/8000 [============================>.] - ETA: 0s - loss: 0.0053 - detector_loss: 0.0202 - picker_P_loss: 0.0042 - picker_S_loss: 0.0047 - detector_f1: 0.9385 - picker_P_f1: 0.5000 - picker_S_f1: 0.3656
# Epoch 00004: val_loss improved from 0.00359 to 0.00349, saving model to /home/volume/workspace/Project/Earthquake/Discriminate-Quarryblast/test_trainer_outputs/models/test_trainer_004.h5
# 8000/8000 [==============================] - 3032s 379ms/step - loss: 0.0053 - detector_loss: 0.0202 - picker_P_loss: 0.0042 - picker_S_loss: 0.0047 - detector_f1: 0.9385 - picker_P_f1: 0.5000 - picker_S_f1: 0.3656 - val_loss: 0.0030 - val_detector_loss: 0.0075 - val_picker_P_loss: 0.0020 - val_picker_S_loss: 0.0032 - val_detector_f1: 0.9729 - val_picker_P_f1: 0.6819 - val_picker_S_f1: 0.4164
#
# Epoch 00005: val_loss improved from 0.00349 to 0.00301, saving model to /home/volume/workspace/Project/Earthquake/Discriminate-Quarryblast/test_trainer_outputs/models/test_trainer_005.h5
# Epoch 6/10
# Learning rate:  0.001
# 8000/8000 [==============================] - 3033s 379ms/step - loss: 0.0052 - detector_loss: 0.0195 - picker_P_loss: 0.0041 - picker_S_loss: 0.0046 - detector_f1: 0.9394 - picker_P_f1: 0.5086 - picker_S_f1: 0.3773 - val_loss: 0.0033 - val_detector_loss: 0.0067 - val_picker_P_loss: 0.0019 - val_picker_S_loss: 0.0031 - val_detector_f1: 0.9760 - val_picker_P_f1: 0.6761 - val_picker_S_f1: 0.4504
#
# Epoch 00006: val_loss did not improve from 0.00301
# Epoch 7/10
# Learning rate:  0.001
# 8000/8000 [==============================] - 3039s 380ms/step - loss: 0.0052 - detector_loss: 0.0190 - picker_P_loss: 0.0041 - picker_S_loss: 0.0045 - detector_f1: 0.9426 - picker_P_f1: 0.5177 - picker_S_f1: 0.3899 - val_loss: 0.0030 - val_detector_loss: 0.0056 - val_picker_P_loss: 0.0019 - val_picker_S_loss: 0.0031 - val_detector_f1: 0.9803 - val_picker_P_f1: 0.6895 - val_picker_S_f1: 0.4758
#
# Epoch 00007: val_loss improved from 0.00301 to 0.00298, saving model to /home/volume/workspace/Project/Earthquake/Discriminate-Quarryblast/test_trainer_outputs/models/test_trainer_007.h5
# Epoch 8/10
# Learning rate:  0.001
# 8000/8000 [==============================] - 3035s 379ms/step - loss: 0.0051 - detector_loss: 0.0183 - picker_P_loss: 0.0040 - picker_S_loss: 0.0045 - detector_f1: 0.9441 - picker_P_f1: 0.5237 - picker_S_f1: 0.3969 - val_loss: 0.0028 - val_detector_loss: 0.0074 - val_picker_P_loss: 0.0019 - val_picker_S_loss: 0.0031 - val_detector_f1: 0.9742 - val_picker_P_f1: 0.6880 - val_picker_S_f1: 0.4710
#
# Epoch 00008: val_loss improved from 0.00298 to 0.00279, saving model to /home/volume/workspace/Project/Earthquake/Discriminate-Quarryblast/test_trainer_outputs/models/test_trainer_008.h5
# Epoch 9/10
# Learning rate:  0.001
# 8000/8000 [==============================] - 3036s 379ms/step - loss: 0.0050 - detector_loss: 0.0180 - picker_P_loss: 0.0040 - picker_S_loss: 0.0045 - detector_f1: 0.9442 - picker_P_f1: 0.5294 - picker_S_f1: 0.4045 - val_loss: 0.0027 - val_detector_loss: 0.0063 - val_picker_P_loss: 0.0019 - val_picker_S_loss: 0.0031 - val_detector_f1: 0.9786 - val_picker_P_f1: 0.6721 - val_picker_S_f1: 0.4599
#
# Epoch 00009: val_loss improved from 0.00279 to 0.00266, saving model to /home/volume/workspace/Project/Earthquake/Discriminate-Quarryblast/test_trainer_outputs/models/test_trainer_009.h5
# Epoch 10/10
# Learning rate:  0.001
# 8000/8000 [==============================] - 3063s 383ms/step - loss: 0.0049 - detector_loss: 0.0173 - picker_P_loss: 0.0039 - picker_S_loss: 0.0044 - detector_f1: 0.9464 - picker_P_f1: 0.5345 - picker_S_f1: 0.4096 - val_loss: 0.0033 - val_detector_loss: 0.0070 - val_picker_P_loss: 0.0019 - val_picker_S_loss: 0.0031 - val_detector_f1: 0.9762 - val_picker_P_f1: 0.6964 - val_picker_S_f1: 0.4943
#
# Epoch 00010: val_loss did not improve from 0.00266

# %%
from EQTransformer.core.tester import tester
tester(input_hdf5='../data/STEAD/merge_modified.hdf5',
       input_testset='test_trainer_outputs/test.npy',
       input_model='test_trainer_outputs/final_model.h5',
       output_name='test_tester',
       detection_threshold=0.50,                
       P_threshold=0.3,
       S_threshold=0.3, 
       number_of_plots=3,
       estimate_uncertainty=False, 
       number_of_sampling=2,
       input_dimention=(6000, 3),
       normalization_mode='std',
       mode='generator',
       batch_size=10,
       gpuid=None,
       gpu_limit=None)
# Out:
# Loading the model ...!
# Loading is complete!!!
# Testing ...
# Writting results into: " test_tester_outputs "
# 100%|██████████| 1000/1000 [18:18<00:00,  1.18s/it]

# %%
import tensorflow as tf
tf.gfile = tf.compat.v1.gfile
tf.GraphDef = tf.compat.v1.GraphDef
tf.profiler = tf.compat.v1.profiler
run_meta = tf.compat.v1.RunMetadata()

def load_pb(pb_model):
    with tf.gfile.GFile(pb_model, "rb") as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())
    with tf.Graph().as_default() as graph:
        tf.import_graph_def(graph_def, name='')
        return graph

def estimate_flops(pb_model):
    graph = load_pb(pb_model)
    with graph.as_default():
        # placeholder input would result in incomplete shape. So replace it with constant during model frozen.
        flops = tf.profiler.profile(graph, run_meta=run_meta, cmd='op', options=tf.profiler.ProfileOptionBuilder.float_operation())
        print('Model {} needs {} FLOPS after freezing'.format(pb_model, flops.total_float_ops))

model = "test_trainer_outputs/final_model.h5"
estimate_flops(model)
# Out:
# Model test_trainer_outputs/final_model.h5 needs 0 FLOPS after freezing
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: Unexpected end-group tag: Not all data was converted
#   # Remove the CWD from sys.path while we load stuff.

# %%
import numpy as np

parameters = np.array([373495, 184416, 229335, 64320, 39776])
FLOPs = np.array([79687040, (1478880+3465216)*4, (15590240+204544)*4, (1478880+204544)*4, 5271488])

Detections_F1 = np.array([0.9973, 0.9962, 0.9995, 0.9974, 0.9949])
P_F1 = np.array([0.9942, 0.9922, 0.9966, 0.9926, 0.9896])
S_F1 = np.array([0.9731, 0.9731, 0.9936, 0.9821, 0.9710])
F1 = (Detections_F1 + P_F1 + S_F1)/3

ID_D = Detections_F1/parameters
ID_P = P_F1/parameters
ID_S = S_F1/parameters
ID = (ID_S + ID_P + ID_D)/3
FLOPs
# Out:
# array([79687040, 19776384, 63179136,  6733696,  5271488])

# %%
ID_D
# Out:
# array([2.67018300e-06, 5.40191740e-06, 4.35825321e-06, 1.55068408e-05,
#        2.50125704e-05])

# %%
ID_P
# Out:
# array([2.66188302e-06, 5.38022731e-06, 4.34560795e-06, 1.54322139e-05,
#        2.48793242e-05])

# %%
ID_S
# Out:
# array([2.60538963e-06, 5.27665712e-06, 4.33252665e-06, 1.52689677e-05,
#        2.44117056e-05])

# %%
ID
# Out:
# array([2.64581855e-06, 5.35293395e-06, 4.34546261e-06, 1.54026741e-05,
#        2.47678667e-05])

# %%
F1 = (Detections + P + S)/3
F1
# Out:
# array([0.9882    , 0.98716667, 0.99656667, 0.9907    , 0.98516667])

# %%
(0.90+0.61+0.60)/3/108691
# Out:
# 6.470943623053733e-06

# %%
def Netscore(a, p, m):
    netscore = list()
    for idx in range(len(a)):
        netscore.append(20*np.log10((a[idx]*100)**2/((p[idx]**0.5)*(m[idx]**0.1))))
    return netscore

Netscore(F1, parameters, FLOPs)
# Out:
# [8.268170669254495,
#  12.525339538820553,
#  10.734403506796594,
#  18.097719150698445,
#  20.30031084453737]
